# %% [markdown]
# <a href="https://colab.research.google.com/github/brayanricardo13/Analisis-Econometrico/blob/main/Fidecomercio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import workbook , load_workbook 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf # Regresion multiple
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor
import statsmodels.api as sm
import statistics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
Fincomercio = pd.read_excel("/content/drive/MyDrive/U CENTRAL ECONOMÍA/PRACTICAS/PRUEBAS /RIESGOS-FIDECOMERCIO/Base_Modelo.xlsx", sheet_name="Hoja3",header=0, index_col=None) 
Fincomercio.head()

# %%
Fincomercio.info()

# %%
Fincomercio.describe().T
# Out:
#                             count          mean           std       min  \
# ID_ASOCIADO                3425.0  5.350247e+04  1.916881e+03   50228.0
# MORA_ACTUAL_CAJA           3390.0  0.000000e+00  0.000000e+00       0.0
# MORA_ACTUAL_LIBRANZA       3397.0  6.181925e-02  1.205726e+00       0.0
# MORA_ACTUAL_BURO_EXTERNO   3425.0  3.658394e-01  1.852364e+00       0.0
# SALDOS_CREDITOS            3425.0  3.383131e+06  6.882370e+06       0.0
# INGRESO                    3425.0  1.652278e+06  2.092729e+06  877803.0
# NUM_PERSONAS_A_CARGO       3425.0  1.089927e+00  1.026276e+00       0.0
# ESTRATO_CORE               3421.0  2.408945e+00  7.498316e-01       1.0
# MORA_MAX_ULTIMOS_12_MESES  3425.0  1.415328e+01  1.043322e+02     -60.0
#
#                                 25%        50%        75%          max
# ID_ASOCIADO                 51838.0    53467.0    55073.0      56945.0
# MORA_ACTUAL_CAJA                0.0        0.0        0.0          0.0
# ...
