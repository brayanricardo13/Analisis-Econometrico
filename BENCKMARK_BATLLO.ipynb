# %% [markdown]
# <a href="https://colab.research.google.com/github/brayanricardo13/Analisis-Econometrico/blob/main/BENCKMARK_BATLLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
BAT_Indices = pd.read_excel("/content/BMK BAT.xlsx",sheet_name="Vlr Unidad")

# %%
inicio_fila = 6  # Fila desde la que comenzar a leer los datos
# Leer los datos desde el archivo Excel
data = pd.read_excel(archivo_excel, sheet_name=hoja, header=None, skiprows=inicio_fila-1, usecols="B:C", names=["Fechas", "Valores"])
# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(data["Fechas"], data["Valores"])
plt.title("Multiescala davivienda")
plt.xlabel("Fechas")
plt.ylabel("Valores")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Mostrar el gráfico
plt.show()

# %%
# Leer los datos desde el archivo Excel
data = pd.read_excel(archivo_excel, sheet_name=hoja, header=None, skiprows=inicio_fila-1, usecols="B,D", names=["Fechas", "Valores"])
# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(data["Fechas"], data["Valores"])
plt.title("FIC plazo 30 BBVA")
plt.xlabel("Fechas")
plt.ylabel("Valores")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Mostrar el gráfico
plt.show()

# %%
# Leer los datos desde el archivo Excel
data = pd.read_excel(archivo_excel, sheet_name=hoja, header=None, skiprows=inicio_fila-1, usecols="B,E", names=["Fechas", "Valores"])
# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(data["Fechas"], data["Valores"])
plt.title("IPC DANE")
plt.xlabel("Fechas")
plt.ylabel("Valores")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Mostrar el gráfico
plt.show()

# %%
# Leer los datos desde el archivo Excel
data = pd.read_excel(archivo_excel, sheet_name=hoja, header=None, skiprows=inicio_fila-1, usecols="B,F", names=["Fechas", "Valores"])
# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(data["Fechas"], data["Valores"])
plt.title("COLTES CP BVC ")
plt.xlabel("Fechas")
plt.ylabel("Valores")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Mostrar el gráfico
plt.show()

# %%
# Leer los datos desde el archivo Excel
data = pd.read_excel(archivo_excel, sheet_name=hoja, header=None, skiprows=inicio_fila-1, usecols="B,G", names=["Fechas", "Valores"])
# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(data["Fechas"], data["Valores"])
plt.title("COLCAP")
plt.xlabel("Fechas")
plt.ylabel("Valores")
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
# Mostrar el gráfico
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-66d7b4857770> in <cell line: 9>()
#       7 inicio_fila = 2  # Ajusta según el inicio de tus datos
#       8
# ----> 9 data = pd.read_excel(archivo_excel, sheet_name=hoja, header=None, skiprows=inicio_fila-1, usecols="B,G", names=["Fechas", "Valores"])
#      10
#      11 # Escalar los valores a base 1000
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# ...
